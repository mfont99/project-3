# %%
# imports and dependencies
import pandas as pd
from pathlib import Path

# %%
# read in the .csv
medicare_data = pd.read_csv('Medicare_Part_D_Prescribing_Rates_by_County.csv')

medicare_df = pd.DataFrame(medicare_data)
medicare_df.head(30)
# Out:
#     Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd      Prscrbr_Geo_Desc  RUCA_Cd  \
# 0   2021        National             NaN              National      NaN
# 1   2021        National             NaN              National      NaN
# 2   2021        National             NaN              National      NaN
# 3   2021           State             1.0               Alabama      NaN
# 4   2021           State             2.0                Alaska      NaN
# 5   2021           State             4.0               Arizona      NaN
# 6   2021           State             5.0              Arkansas      NaN
# 7   2021           State             6.0            California      NaN
# 8   2021           State             8.0              Colorado      NaN
# 9   2021           State             9.0           Connecticut      NaN
# 10  2021           State            10.0              Delaware      NaN
# 11  2021           State            11.0  District of Columbia      NaN
# ...

# %%
# renaming columns
medicare_df = medicare_df.rename(columns={"Prscrbr_Geo_Cd":"FIPS", "Opioid_Prscrbng_Rate_5Y_Chg":"5Y_Chg", "Opioid_Prscrbng_Rate_1Y_Chg":"1Y_Chg","LA_Opioid_Prscrbng_Rate_5Y_Chg":"LA_5Y_Chg","LA_Opioid_Prscrbng_Rate_1Y_Chg":"LA_1Y_Chg","RUCA_Cd":"RUCA"})

# dropping "breakout_type" column
# medicare_df = medicare_df.drop(columns={"Breakout_Type"})

# display updated df
medicare_df.tail(30)
# Out:
#         Year Prscrbr_Geo_Lvl     FIPS                    Prscrbr_Geo_Desc  \
# 268834  2013             ZIP  99709.0   Alaska:Fairbanks North Star:99709
# 268835  2013             ZIP  99710.0   Alaska:Fairbanks North Star:99710
# 268836  2013             ZIP  99722.0          Alaska:Yukon-Koyukuk:99722
# 268837  2013             ZIP  99723.0            Alaska:North Slope:99723
# 268838  2013             ZIP  99730.0          Alaska:Yukon-Koyukuk:99730
# 268839  2013             ZIP  99737.0    Alaska:Southeast Fairbanks:99737
# 268840  2013             ZIP  99740.0          Alaska:Yukon-Koyukuk:99740
# 268841  2013             ZIP  99741.0          Alaska:Yukon-Koyukuk:99741
# 268842  2013             ZIP  99752.0       Alaska:Northwest Arctic:99752
# 268843  2013             ZIP  99755.0                 Alaska:Denali:99755
# 268844  2013             ZIP  99762.0                   Alaska:Nome:99762
# 268845  2013             ZIP  99775.0   Alaska:Fairbanks North Star:99775
# ...

# %%
# export to a new .csv
medicare_df.to_csv("Medicare_Part_D_Cleaned.csv", index=False)
