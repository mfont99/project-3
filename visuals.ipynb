# %%
# Import the dependencies.
from pathlib import Path
from sqlalchemy import create_engine
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
link = Path("../project-3/Resources/filtered_data.csv")
filter_file = pd.read_csv(link, dtype={'FIPS': str, 'Year': int, 'State': str, 'ST': str, 'FIPS State': str, 'County': str, 'Population': int, 'Est. Age-Adj death rate (in ranges)': str})

# %%
county_counts = filter_file.groupby(['State', 'Year']).size().reset_index(name='count')
county_counts
# Out:
#              State  Year  count
# 0           Alaska  2015      1
# 1          Arizona  2013      1
# 2          Arizona  2014      1
# 3          Arizona  2015      3
# 4       California  2011      1
# ..             ...   ...    ...
# 139  West Virginia  2011      8
# 140  West Virginia  2012      9
# 141  West Virginia  2013     10
# 142  West Virginia  2014     14
# 143  West Virginia  2015     17
#
# [144 rows x 3 columns]

# %%
# Set up the plot
plt.figure(figsize=(34, 27))

# Create the distribution plot
sns.barplot(data=county_counts, x='State', y='count', hue='Year')

# Add titles and labels
plt.title('Number of Counties with Age-Adjusted Death Rates >30 by State and Year')
plt.xlabel('State')
plt.ylabel('Number of Counties')
plt.xticks(rotation=90)
plt.legend(title='Year')
plt.tight_layout()
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       2 plt.figure(figsize=(34, 27))
#       4 # Create the distribution plot
# ----> 5 sns.barplot(data=county_counts, x='State', y='count', hue='Year')
#       7 # Add titles and labels
#       8 plt.title('Number of Counties with Age-Adjusted Death Rates >30 by State and Year')
#
# File c:\Users\openbox\anaconda3\envs\dev\lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File c:\Users\openbox\anaconda3\envs\dev\lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
# ...
