# %%
# Dependencies
import pandas as pd
from pathlib import Path
import os
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Url1 = Path("../project-3/Resources/data_file.csv")
Url2 = Path("../project-3/Resources/Medicare_Part_D_Cleaned.csv")
Url3 = Path("../project-3/Resources/filtered_data.csv")

death_file = pd.read_csv(Url1)
presc_file = pd.read_csv(Url2)
filter_file = pd.read_csv(Url3)

# %%
presc_file
# Out:
#         Year Prscrbr_Geo_Lvl     FIPS                    Prscrbr_Geo_Desc  \
# 0       2021        National      NaN                            National
# 1       2021        National      NaN                            National
# 2       2021        National      NaN                            National
# 3       2021           State      1.0                             Alabama
# 4       2021           State      2.0                              Alaska
# ...      ...             ...      ...                                 ...
# 268859  2013             ZIP  99921.0  Alaska:Prince of Wales-Hyder:99921
# 268860  2013             ZIP  99922.0  Alaska:Prince of Wales-Hyder:99922
# 268861  2013             ZIP  99925.0  Alaska:Prince of Wales-Hyder:99925
# 268862  2013             ZIP  99926.0  Alaska:Prince of Wales-Hyder:99926
# 268863  2013             ZIP  99929.0               Alaska:Wrangell:99929
#
#         RUCA Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  Tot_Opioid_Clms  \
# ...

# %%
death_file.head()
# Out:
#    FIPS  Year   State  ST  FIPS State                          County  \
# 0  2290  2007  Alaska  AK           2   Yukon-Koyukuk Census Area, AK
# 1  2016  2009  Alaska  AK           2  Aleutians West Census Area, AK
# 2  2170  2004  Alaska  AK           2   Matanuska-Susitna Borough, AK
# 3  2180  2003  Alaska  AK           2            Nome Census Area, AK
# 4  2016  2000  Alaska  AK           2  Aleutians West Census Area, AK
#
#    Population Est. Age-Adj death rate (in ranges)
# 0      5712.0                              8.1-10
# 1      5537.0                             10.1-12
# 2     70761.0                             10.1-12
# 3      9210.0                               4.1-6
# 4      5470.0                               2.1-4

# %%
death_file = death_file.rename(columns={"FIPS":"County FIPS"})
death_file
# Out:
#        County FIPS  Year    State  ST  FIPS State  \
# 0             2290  2007   Alaska  AK           2
# 1             2016  2009   Alaska  AK           2
# 2             2170  2004   Alaska  AK           2
# 3             2180  2003   Alaska  AK           2
# 4             2016  2000   Alaska  AK           2
# ...            ...   ...      ...  ..         ...
# 53382        56003  2006  Wyoming  WY          56
# 53383        56007  2001  Wyoming  WY          56
# 53384        56035  2003  Wyoming  WY          56
# 53385        56001  2000  Wyoming  WY          56
# 53386        56029  1999  Wyoming  WY          56
#
#                                County  Population  \
# 0       Yukon-Koyukuk Census Area, AK      5712.0
# 1      Aleutians West Census Area, AK      5537.0
# 2       Matanuska-Susitna Borough, AK     70761.0
# 3                Nome Census Area, AK      9210.0
# 4      Aleutians West Census Area, AK      5470.0
# ...                               ...         ...
# ...

# %%
death_file = death_file.rename(columns={"FIPS State":"FIPS"})
death_file
# Out:
#        County FIPS  Year    State  ST  FIPS                          County  \
# 0             2290  2007   Alaska  AK     2   Yukon-Koyukuk Census Area, AK
# 1             2016  2009   Alaska  AK     2  Aleutians West Census Area, AK
# 2             2170  2004   Alaska  AK     2   Matanuska-Susitna Borough, AK
# 3             2180  2003   Alaska  AK     2            Nome Census Area, AK
# 4             2016  2000   Alaska  AK     2  Aleutians West Census Area, AK
# ...            ...   ...      ...  ..   ...                             ...
# 53382        56003  2006  Wyoming  WY    56             Big Horn County, WY
# 53383        56007  2001  Wyoming  WY    56               Carbon County, WY
# 53384        56035  2003  Wyoming  WY    56             Sublette County, WY
# 53385        56001  2000  Wyoming  WY    56               Albany County, WY
# 53386        56029  1999  Wyoming  WY    56                 Park County, WY
#
#        Population Est. Age-Adj death rate (in ranges)
# ...

# %%
merged_df = pd.merge(presc_file, death_file, on=['FIPS','Year'], how='left')
merged_df
# Out:
#         Year Prscrbr_Geo_Lvl     FIPS                    Prscrbr_Geo_Desc  \
# 0       2021        National      NaN                            National
# 1       2021        National      NaN                            National
# 2       2021        National      NaN                            National
# 3       2021           State      1.0                             Alabama
# 4       2021           State      2.0                              Alaska
# ...      ...             ...      ...                                 ...
# 296663  2013             ZIP  99921.0  Alaska:Prince of Wales-Hyder:99921
# 296664  2013             ZIP  99922.0  Alaska:Prince of Wales-Hyder:99922
# 296665  2013             ZIP  99925.0  Alaska:Prince of Wales-Hyder:99925
# 296666  2013             ZIP  99926.0  Alaska:Prince of Wales-Hyder:99926
# 296667  2013             ZIP  99929.0               Alaska:Wrangell:99929
#
#         RUCA Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  Tot_Opioid_Clms  \
# ...

# %%
filter_file
# Out:
#       FIPS  Year          State  ST  FIPS State  \
# 0     2280  2015         Alaska  AK           2
# 1     4012  2013        Arizona  AZ           4
# 2     4012  2014        Arizona  AZ           4
# 3     4012  2015        Arizona  AZ           4
# 4     4007  2015        Arizona  AZ           4
# ..     ...   ...            ...  ..         ...
# 546  54045  2011  West Virginia  WV          54
# 547  54075  2015  West Virginia  WV          54
# 548  54109  2004  West Virginia  WV          54
# 549  54059  2012  West Virginia  WV          54
# 550  54047  2009  West Virginia  WV          54
#
#                                   County  Population  \
# 0    Wrangell-Petersburg Census Area, AK      3177.0
# 1                      La Paz County, AZ     20377.0
# 2                      La Paz County, AZ     20314.0
# 3                      La Paz County, AZ     20152.0
# 4                        Gila County, AZ     53159.0
# ..                                   ...         ...
# ...
